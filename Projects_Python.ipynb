# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
df=pd.read_csv("Financial.csv",sep=",")
df
# Out:
#               Segment                   Country     Product   Discount Band
# 0          Government                    Canada   Carretera            None   \
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %%
df.shape
# Out:
# (700, 16)

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold
# 0  Government   Canada   Carretera            None       1618.5  \
# 1  Government  Germany   Carretera            None       1321.0
# 2   Midmarket   France   Carretera            None       2178.0
# 3   Midmarket  Germany   Carretera            None        888.0
# 4   Midmarket   Mexico   Carretera            None       2470.0
#
#     Manufacturing Price    Sale Price    Gross Sales   Discounts     Sales
# 0                      3            20        32370.0        -      32370.0  \
# 1                      3            20        26420.0        -      26420.0
# 2                      3            15        32670.0        -      32670.0
# 3                      3            15        13320.0        -      13320.0
# 4                      3            15        37050.0        -      37050.0
#
#      COGS   Profit         Date  Month Number  Month Name   Year
# ...

# %%
df.dtypes
# Out:
# Segment                   object
# Country                   object
#  Product                  object
#  Discount Band            object
# Units Sold               float64
#  Manufacturing Price       int64
#  Sale Price                int64
#  Gross Sales             float64
#  Discounts                object
#   Sales                  float64
#  COGS                    float64
#  Profit                   object
# Date                      object
# Month Number               int64
#  Month Name               object
# Year                       int64
# dtype: object

# %%
df.describe()
# Out:
#         Units Sold   Manufacturing Price    Sale Price    Gross Sales
# count   700.000000             700.000000    700.000000   7.000000e+02  \
# mean   1608.294286              96.477143    118.428571   1.827594e+05
# std     867.427859             108.602612    136.775515   2.542623e+05
# min     200.000000               3.000000      7.000000   1.799000e+03
# 25%     905.000000               5.000000     12.000000   1.739175e+04
# 50%    1542.500000              10.000000     20.000000   3.798000e+04
# 75%    2229.125000             250.000000    300.000000   2.790250e+05
# max    4492.500000             260.000000    350.000000   1.207500e+06
#
#              Sales           COGS   Month Number         Year
# count  7.000000e+02     700.000000    700.000000   700.000000
# mean   1.696091e+05  145475.211429      7.900000  2013.750000
# std    2.367263e+05  203865.506118      3.377321     0.433322
# min    1.655080e+03     918.000000      1.000000  2013.000000
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dropna(inplace=True)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 695    False
# 696    False
# 697    False
# 698    False
# 699    False
# Length: 700, dtype: bool

# %%
df.nunique()
# Out:
# Segment                    5
# Country                    5
#  Product                   6
#  Discount Band             4
# Units Sold               510
#  Manufacturing Price       6
#  Sale Price                7
#  Gross Sales             550
#  Discounts               515
#   Sales                  559
#  COGS                    545
#  Profit                  557
# Date                      16
# Month Number              12
#  Month Name               12
# Year                       2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Segment', 'Country', ' Product ', ' Discount Band ', 'Units Sold',
#        ' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ',
#        '  Sales ', ' COGS ', ' Profit ', 'Date', 'Month Number',
#        ' Month Name ', 'Year'],
#       dtype='object')

# %%
df['Country'].value_counts()
# Out:
# Country
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140
# Name: count, dtype: int64

# %%
Profit_per_country = df.groupby('Country')[' Profit '].sum()
Profit_per_country
# Out:
# Country
# Canada                      161852266213327.517252920226621552501076018170...
# France                      1089018990274590201089013743010755024750018990...
# Germany                     1321044401361704605139054292905403303136170194...
# Mexico                      1235012350479004870176639400123602986104665232...
# United States of America    3075228682081410517577192692286307516499.04488...
# Name:  Profit , dtype: object

# %%
plt.bar(Profit_per_country.index, Profit_per_country.index)
plt.xlabel('Country')
plt.ylabel('Total Profit')
plt.title('Total Profit by Country')
plt.show()

# %%
sales_per_country = df.groupby('Country')['  Sales '].sum()

plt.bar(sales_per_country.index, sales_per_country.values)
plt.xlabel('Country')
plt.ylabel('Total Sales')
plt.title('Total Sales by Country')
plt.show()

# %%
profit_per_year = df.groupby('Year')[' Profit '].sum()

plt.plot(profit_per_year.index, profit_per_year.index, marker='o')
plt.xlabel('Year')
plt.ylabel('Total Profit')
plt.title('Total Profit per Year')
plt.show()

# %%
sns.scatterplot(x='Units Sold', y=' Profit ', data=df)
plt.xlabel('Units Sold')
plt.ylabel('Profit')
plt.title('Scatter plot: Units Sold vs. Profit')
plt.show()

# %%
numerical_columns = df.select_dtypes(include='number')
numerical_columns
# Out:
#      Units Sold   Manufacturing Price    Sale Price    Gross Sales
# 0        1618.5                      3            20        32370.0  \
# 1        1321.0                      3            20        26420.0
# 2        2178.0                      3            15        32670.0
# 3         888.0                      3            15        13320.0
# 4        2470.0                      3            15        37050.0
# ..          ...                    ...           ...            ...
# 695      2475.0                    260           300       742500.0
# 696       546.0                    260           300       163800.0
# 697      1368.0                      5             7         9576.0
# 698       723.0                     10             7         5061.0
# 699      1806.0                    250            12        21672.0
#
#         Sales      COGS   Month Number  Year
# 0     32370.00   16185.0             1  2014
# 1     26420.00   13210.0             1  2014
# ...

# %%
correlation_matrix = numerical_columns.corr()
correlation_matrix
# Out:
#                        Units Sold   Manufacturing Price    Sale Price
# Units Sold               1.000000              -0.029644 -6.506581e-02  \
#  Manufacturing Price    -0.029644               1.000000  7.078637e-02
#  Sale Price             -0.065066               0.070786  1.000000e+00
#  Gross Sales             0.327221               0.049852  8.082502e-01
#   Sales                  0.326914               0.051549  8.058777e-01
#  COGS                    0.331694               0.046857  7.993354e-01
# Month Number            -0.103607               0.005021  5.122894e-17
# Year                     0.063857              -0.000927 -4.211383e-15
#
#                         Gross Sales     Sales      COGS   Month Number
# Units Sold                  0.327221  0.326914  0.331694 -1.036069e-01  \
#  Manufacturing Price        0.049852  0.051549  0.046857  5.021388e-03
#  Sale Price                 0.808250  0.805878  0.799335  5.122894e-17
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Heatmap Correlation Plot')
plt.show()

# %%
selected_columns = ['Units Sold',' Manufacturing Price ', ' Sale Price ', ' Gross Sales ', ' Discounts ', ' Profit ']

sns.pairplot(df[selected_columns])
plt.suptitle('Pair Plot of Selected Numerical Columns', y=1.02)
plt.show()

# %%
profit_by_segment = df.groupby('Segment')[' Profit '].sum()

profit_by_country = df.groupby('Country')[' Profit '].sum()

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.bar(profit_by_segment.index, profit_by_segment.index)
plt.xlabel('Segment')
plt.ylabel('Total Profit')
plt.title('Total Profit by Segment')


plt.subplot(1, 2, 2)
plt.bar(profit_by_country.index, profit_by_country.index)
plt.xlabel('Country')
plt.ylabel('Total Profit')
plt.title('Total Profit by Country')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %%
sales_data = df['  Sales ']

plt.figure(figsize=(8, 6))
plt.hist(sales_data, bins=20, edgecolor='black')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Histogram of Sales')
plt.grid()
plt.show()

# %%
sales_per_country = df.groupby('Country')['  Sales '].sum()

plt.figure(figsize=(8, 8))
plt.pie(sales_per_country, labels=sales_per_country.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Sales per Country')
plt.show()
